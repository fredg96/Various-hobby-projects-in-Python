# %% [markdown]
# # Generating synthetic faces using a variational autoencoder, VAE
# In this notebook a variational autoencoder will be implemented and trained using the "CelebA" dataset from kaggle. There will note be any mathematical proof here but the math can be found fairly easily.

# %% [markdown]
# A variational autoencoder consists of two main parts, a decoder, and an encoder. The role of the encoder is to take data and reduce the dimension in order to be able to represent it in a lower dimensional space, similar to what PCA does. The decoder is then trained to take data from this lower dimension and reconstruct it back to the higher dimension. Thereby the input to the encoder is data of dimension X while the ouput has the dimension x, which is smaller. The input to the encoder then has teh dimension x while the output of the decoder has the dimension X hence feeding an image through the encoder and then the decoder shouyld ideally result in the same image, though reconstruction losses will make the output slightly different as well see.

# %%
import os
from glob import glob
import numpy as np
import tensorflow as tf
import keras
import matplotlib.pyplot as plt

from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint 
from keras.utils import plot_model
from keras.losses import binary_crossentropy,mse
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Since this project is about a variational autoencoder, which works with distributions, we will not decode the data into a sincle vector i.e. going from an input size of 100 down to a size of 10. Instead the encoding will be done to two vectors, one for the mean of the distribution and one for the variance.

# %%
def dynamic_encoder(input_dim, output_dim, nr_filters, kernel_sizes, conv_strides, 
            batch_normalize = False, use_dropout = False):
    
    global K
    K.clear_session()
    
    nr_layers = len(nr_filters)
    
    inputs = Input(shape = input_dim, name = 'encoder_input') 
    x = inputs #Input layer
    
    #In the following loop we add blocks of layers on the form Conv2D followed by Batch normalization, Activation layer and
    #finally a dropout layer, though batch normalization and dropout is optional.
    
    for i in range(nr_layers):
        x = Conv2D(filters = nr_filters[i], kernel_size = kernel_sizes[i],
                  strides = conv_strides[i], padding = 'same',
                  name = 'encoder_layer_' + str(i))(x)
        
        if batch_normalize:
            x = BatchNormalization()(X)
        x = LeakyReLU()(x)
        
        if use_dropout:
            x = Dropout(rate = 0.25)(x)
            
    non_flatten_shape = K.int_shape(x)[1:] #Getting the dimensions of the tensor before flattening it in order to later be able to get images.

    x = Flatten()(x)
    
    mu = Dense(output_dim, name = 'mu')(x) #Adding a layer to get the mean of the distributions of the latent vector
    log_var = Dense(output_dim, name = 'log_var')(x) #Adding a layer to get the variance of the distributions of the latent vector

    #In this case we perform the sampling in the encoder model 
    def sampling(args):
        mu, log_var = args
        epsilon = K.random_normal(shape = K.shape(mu), mean = 0., stddev = 1.)
        return mu + K.exp(log_var/2)*epsilon
    
    output = Lambda(sampling, name = 'encoder_output')([mu, log_var]) #Output layer of the encoder which uses the Lamda layer that samples from mu and log_var
    
    return mu, log_var, inputs, output, non_flatten_shape, Model(inputs, [mu, log_var, output], name = 'Encoder')

# %% [markdown]
# The decoder will be made in the same way as the encoder however we just returns the output of the decoder and the decoder model itself.

# %%
def dynamic_decoder(input_dim, non_flatten_shape, nr_filters, kernel_sizes,
                   conv_strides):
    
    nr_layers = len(nr_filters)
    
    inputs = Input(shape = (input_dim,), name = 'decoder_input')
    
    x = Dense(np.prod(non_flatten_shape))(inputs)
    x = Reshape(non_flatten_shape)(x)
    
    for i in range(nr_layers):
        x = Conv2DTranspose(filters = nr_filters[i], kernel_size = kernel_sizes[i],
                           strides = conv_strides[i], padding = 'same',
                           name = 'decoder_layer_' + str(i))(x)
        
        if i < nr_layers - 1:
            x = LeakyReLU()(x)
        else:
            x = Activation('sigmoid')(x)
            
    output = x
    
    return output, Model(inputs, output, name = 'Decoder')

# %% [markdown]
# To look at how the model performs we'll implement to functions to plot images. The first, "compare_iamges" feeds images to the model and shows the predicted, reconstructed output of the model while the second generates completely new images by using the decoder on values sampled from a normal distribution.

# %%
def compare_images(images, model):
    nr_images = images.shape[0]
    reconstructed = model.predict(images)
    
    fig = plt.figure(figsize = (15,3))
    fig.subplots_adjust(hspace = 0.4, wspace = 0.4)
    
    for i in range(nr_images):
        img  = images[i].squeeze()
        sub = fig.add_subplot(2, nr_images, i + 1)
        sub.axis('off')
        sub.imshow(img)
        
    for i in range(nr_images):
        img  = reconstructed[i].squeeze()
        sub = fig.add_subplot(2, nr_images, i + nr_images + 1)
        sub.axis('off')
        sub.imshow(img)

# %%
def generate_images(model, latent_space, nr_images = 10):
    generated = model.predict(np.random.normal(0, 1, size = (nr_images, latent_space)))
    
    fig = plt.figure(figsize = (15, 3))
    fig.subplots_adjust(hspace = 0.4, wspace = 0.4)
    
    for i in range(nr_images):
        img = generated[i].squeeze()
        sub = fig.add_subplot(2, nr_images, i + 1)
        sub.axis('off')
        sub.imshow(img)

# %% [markdown]
# The main function below is what will drive the whole code. What basically happens is that the encoder and decoder is created whereby they get connected into a vae model which then gets trained. During the training a special loss function is used. This loss function consists of two parts one is the reconstruction loss which meassures how close the reconstruction, output, is to the input. The second part is the so called Kullback-Leibler Divergence which basically meassures how well different distributions fit each others. Another quirk of this project is that we'll use the flow_from_director

# %%
def main():
    height = 128
    width = 128
    nr_channels = 3
    
    batch_size = 512
    learning_rate = 0.0005
    epochs = 150
    
    latent_vector = 200
    image_dim = (height, width, nr_channels)
    
    encoder_filters = [32, 64, 64, 64]
    decoder_filters = [64, 64, 32, 3]
    kernels = [3, 3, 3, 3]
    strides = [2, 2, 2, 2]
    
    current_folder = os.getcwd()
    data_folder = current_folder + '/data/img_align_celeba/'

    filenames = os.listdir(data_folder)
    nr_images = len(filenames)
    print("Total number of images : " + str(nr_images))
    
    data_folder = current_folder + '/data/'

    data_flow = ImageDataGenerator(rescale=1./255).flow_from_directory(data_folder, 
                                                                       target_size = image_dim[:2],
                                                                       batch_size = batch_size,
                                                                       shuffle = True,
                                                                       class_mode = 'input',
                                                                       subset = 'training'
                                                                       )
    
    
    mu, log_var, encoder_in, encoder_out, shape, encoder = dynamic_encoder(image_dim, latent_vector, encoder_filters, kernels, strides) 
    decoder_output, decoder = dynamic_decoder(latent_vector, shape, decoder_filters, kernels, strides)
    
    vae_output = decoder(encoder(encoder_in)[2])
    vae = Model(encoder_in, vae_output)
    def kl_reconstruction_loss(true, pred):
      # Reconstruction loss
        reconstruction_loss = binary_crossentropy(K.flatten(true), K.flatten(pred)) * 128 * 128
      # KL divergence loss
        kl_loss = 1 + log_var - K.square(mu) - K.exp(log_var)
        kl_loss = K.sum(kl_loss, axis=-1)
        kl_loss *= -0.5
      # Total loss = 50% rec + 50% KL divergence loss
        return K.mean(reconstruction_loss + kl_loss)

    vae.compile(optimizer='adam', loss = kl_reconstruction_loss)
    vae.summary()
    callbacks = [ModelCheckpoint('trained_vae.h5', verbose = 1, save_best_only = True, monitor = 'loss')]
    vae.fit(data_flow, 
                        shuffle = True, 
                        epochs = epochs, 
                        callbacks = callbacks,
                        initial_epoch = 0, 
                        steps_per_epoch = nr_images / batch_size
                        )
    examples = next(data_flow)
    examples  = examples[0]
    examples_images = examples[:10]
    print("Comparison of original image and reconstructed image after passing through encoder/decoder" )
    compare_images(examples_images, vae)
    
    print("Newly generated faces.")
    generate_images(decoder, latent_vector)

# %%
main()
# Out:
# Total number of images : 202599
# Found 202599 images belonging to 1 classes.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 128, 128, 3)       0
# _________________________________________________________________
# Encoder (Model)              [(None, 200), (None, 200) 1732048
# _________________________________________________________________
# Decoder (Model)              (None, 128, 128, 3)       916483
# =================================================================
# Total params: 2,648,531
# Trainable params: 2,648,531
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 396/395 [==============================] - 263s 664ms/step - loss: 8993.5267
#
# Epoch 00001: loss improved from inf to 8993.68350, saving model to trained_vae.h5
# Epoch 2/150
# 396/395 [==============================] - 216s 544ms/step - loss: 8424.2638
#
# Epoch 00002: loss improved from 8993.68350 to 8424.16719, saving model to trained_vae.h5
# Epoch 3/150
# 396/395 [==============================] - 203s 512ms/step - loss: 8360.4352
#
# Epoch 00003: loss improved from 8424.16719 to 8360.41895, saving model to trained_vae.h5
# Epoch 4/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8332.2774
#
# Epoch 00004: loss improved from 8360.41895 to 8332.21769, saving model to trained_vae.h5
# Epoch 5/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8316.2011
#
# Epoch 00005: loss improved from 8332.21769 to 8316.24328, saving model to trained_vae.h5
# Epoch 6/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8305.1316
#
# Epoch 00006: loss improved from 8316.24328 to 8305.24502, saving model to trained_vae.h5
# Epoch 7/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8296.3774
#
# Epoch 00007: loss improved from 8305.24502 to 8296.37276, saving model to trained_vae.h5
# Epoch 8/150
# 396/395 [==============================] - 197s 496ms/step - loss: 8290.8193
#
# Epoch 00008: loss improved from 8296.37276 to 8290.77611, saving model to trained_vae.h5
# Epoch 9/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8282.1741
#
# Epoch 00009: loss improved from 8290.77611 to 8282.18301, saving model to trained_vae.h5
# Epoch 10/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8274.7098
#
# Epoch 00010: loss improved from 8282.18301 to 8274.61368, saving model to trained_vae.h5
# Epoch 11/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8269.5105
#
# Epoch 00011: loss improved from 8274.61368 to 8269.58955, saving model to trained_vae.h5
# Epoch 12/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8265.5719
#
# Epoch 00012: loss improved from 8269.58955 to 8265.55569, saving model to trained_vae.h5
# Epoch 13/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8262.0347
#
# Epoch 00013: loss improved from 8265.55569 to 8262.12023, saving model to trained_vae.h5
# Epoch 14/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8259.8685
#
# Epoch 00014: loss improved from 8262.12023 to 8259.78760, saving model to trained_vae.h5
# Epoch 15/150
# 396/395 [==============================] - 199s 501ms/step - loss: 8257.6068
#
# Epoch 00015: loss improved from 8259.78760 to 8257.57572, saving model to trained_vae.h5
# Epoch 16/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8255.2368
#
# Epoch 00016: loss improved from 8257.57572 to 8255.18768, saving model to trained_vae.h5
# Epoch 17/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8253.1936
#
# Epoch 00017: loss improved from 8255.18768 to 8253.18217, saving model to trained_vae.h5
# Epoch 18/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8251.4497
#
# Epoch 00018: loss improved from 8253.18217 to 8251.51476, saving model to trained_vae.h5
# Epoch 19/150
# 396/395 [==============================] - 202s 510ms/step - loss: 8250.7053
#
# Epoch 00019: loss improved from 8251.51476 to 8250.71364, saving model to trained_vae.h5
# Epoch 20/150
# 396/395 [==============================] - 200s 505ms/step - loss: 8247.8658
#
# Epoch 00020: loss improved from 8250.71364 to 8247.87623, saving model to trained_vae.h5
# Epoch 21/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8247.4551
#
# Epoch 00021: loss improved from 8247.87623 to 8247.42383, saving model to trained_vae.h5
# Epoch 22/150
# 396/395 [==============================] - 197s 498ms/step - loss: 8245.9545
#
# Epoch 00022: loss improved from 8247.42383 to 8245.94816, saving model to trained_vae.h5
# Epoch 23/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8245.3299
#
# Epoch 00023: loss improved from 8245.94816 to 8245.33771, saving model to trained_vae.h5
# Epoch 24/150
# 396/395 [==============================] - 196s 496ms/step - loss: 8244.5282
#
# Epoch 00024: loss improved from 8245.33771 to 8244.50668, saving model to trained_vae.h5
# Epoch 25/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8242.8972
#
# Epoch 00025: loss improved from 8244.50668 to 8242.93186, saving model to trained_vae.h5
# Epoch 26/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8241.9807
#
# Epoch 00026: loss improved from 8242.93186 to 8242.03601, saving model to trained_vae.h5
# Epoch 27/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8242.0233
#
# Epoch 00027: loss did not improve from 8242.03601
# Epoch 28/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8240.4183
#
# Epoch 00028: loss improved from 8242.03601 to 8240.35942, saving model to trained_vae.h5
# Epoch 29/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8239.9558
#
# Epoch 00029: loss improved from 8240.35942 to 8239.95102, saving model to trained_vae.h5
# Epoch 30/150
# 396/395 [==============================] - 197s 498ms/step - loss: 8238.9648
#
# Epoch 00030: loss improved from 8239.95102 to 8238.87561, saving model to trained_vae.h5
# Epoch 31/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8238.7354
#
# Epoch 00031: loss improved from 8238.87561 to 8238.69429, saving model to trained_vae.h5
# Epoch 32/150
# 396/395 [==============================] - 196s 496ms/step - loss: 8237.9786
#
# Epoch 00032: loss improved from 8238.69429 to 8237.99425, saving model to trained_vae.h5
# Epoch 33/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8237.5649
#
# Epoch 00033: loss improved from 8237.99425 to 8237.53862, saving model to trained_vae.h5
# Epoch 34/150
# 396/395 [==============================] - 198s 499ms/step - loss: 8236.9128
#
# Epoch 00034: loss improved from 8237.53862 to 8236.89793, saving model to trained_vae.h5
# Epoch 35/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8236.4927
#
# Epoch 00035: loss improved from 8236.89793 to 8236.41942, saving model to trained_vae.h5
# Epoch 36/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8235.9018
#
# Epoch 00036: loss improved from 8236.41942 to 8235.87230, saving model to trained_vae.h5
# Epoch 37/150
# 396/395 [==============================] - 199s 503ms/step - loss: 8235.6760
#
# Epoch 00037: loss improved from 8235.87230 to 8235.66403, saving model to trained_vae.h5
# Epoch 38/150
# 396/395 [==============================] - 202s 510ms/step - loss: 8235.0355
#
# Epoch 00038: loss improved from 8235.66403 to 8234.92412, saving model to trained_vae.h5
# Epoch 39/150
# 396/395 [==============================] - 200s 506ms/step - loss: 8234.7579
#
# Epoch 00039: loss improved from 8234.92412 to 8234.79083, saving model to trained_vae.h5
# Epoch 40/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8234.3929
#
# Epoch 00040: loss improved from 8234.79083 to 8234.39344, saving model to trained_vae.h5
# Epoch 41/150
# 396/395 [==============================] - 197s 499ms/step - loss: 8233.8968
#
# Epoch 00041: loss improved from 8234.39344 to 8233.89693, saving model to trained_vae.h5
# Epoch 42/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8233.5812
#
# Epoch 00042: loss improved from 8233.89693 to 8233.45652, saving model to trained_vae.h5
# Epoch 43/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8233.0432
#
# Epoch 00043: loss improved from 8233.45652 to 8233.06390, saving model to trained_vae.h5
# Epoch 44/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8232.9541
#
# Epoch 00044: loss improved from 8233.06390 to 8232.93002, saving model to trained_vae.h5
# Epoch 45/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8232.4306
#
# Epoch 00045: loss improved from 8232.93002 to 8232.45284, saving model to trained_vae.h5
# Epoch 46/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8232.0914
#
# Epoch 00046: loss improved from 8232.45284 to 8232.12980, saving model to trained_vae.h5
# Epoch 47/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8231.9071
#
# Epoch 00047: loss improved from 8232.12980 to 8231.90517, saving model to trained_vae.h5
# Epoch 48/150
# 396/395 [==============================] - 198s 499ms/step - loss: 8231.8143
#
# Epoch 00048: loss improved from 8231.90517 to 8231.78909, saving model to trained_vae.h5
# Epoch 49/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8231.1479
#
# Epoch 00049: loss improved from 8231.78909 to 8231.10346, saving model to trained_vae.h5
# Epoch 50/150
# 396/395 [==============================] - 198s 499ms/step - loss: 8230.8188
#
# Epoch 00050: loss improved from 8231.10346 to 8230.93552, saving model to trained_vae.h5
# Epoch 51/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8230.8611
#
# Epoch 00051: loss improved from 8230.93552 to 8230.81717, saving model to trained_vae.h5
# Epoch 52/150
# 396/395 [==============================] - 196s 496ms/step - loss: 8230.2786
#
# Epoch 00052: loss improved from 8230.81717 to 8230.26962, saving model to trained_vae.h5
# Epoch 53/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8230.5804
#
# Epoch 00053: loss did not improve from 8230.26962
# Epoch 54/150
# 396/395 [==============================] - 199s 504ms/step - loss: 8229.8140
#
# Epoch 00054: loss improved from 8230.26962 to 8229.73554, saving model to trained_vae.h5
# Epoch 55/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8229.6145
#
# Epoch 00055: loss improved from 8229.73554 to 8229.67969, saving model to trained_vae.h5
# Epoch 56/150
# 396/395 [==============================] - 199s 501ms/step - loss: 8229.7157
#
# Epoch 00056: loss did not improve from 8229.67969
# Epoch 57/150
# 396/395 [==============================] - 201s 508ms/step - loss: 8229.3605
#
# Epoch 00057: loss improved from 8229.67969 to 8229.41762, saving model to trained_vae.h5
# Epoch 58/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8228.9265
#
# Epoch 00058: loss improved from 8229.41762 to 8229.03501, saving model to trained_vae.h5
# Epoch 59/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8228.9074
#
# Epoch 00059: loss improved from 8229.03501 to 8228.83086, saving model to trained_vae.h5
# Epoch 60/150
# 396/395 [==============================] - 197s 498ms/step - loss: 8228.8927
#
# Epoch 00060: loss improved from 8228.83086 to 8228.83073, saving model to trained_vae.h5
# Epoch 61/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8228.3751
#
# Epoch 00061: loss improved from 8228.83073 to 8228.32305, saving model to trained_vae.h5
# Epoch 62/150
# 396/395 [==============================] - 198s 499ms/step - loss: 8228.2276
#
# Epoch 00062: loss improved from 8228.32305 to 8228.31822, saving model to trained_vae.h5
# Epoch 63/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8228.0237
#
# Epoch 00063: loss improved from 8228.31822 to 8228.02105, saving model to trained_vae.h5
# Epoch 64/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8227.7728
#
# Epoch 00064: loss improved from 8228.02105 to 8227.78049, saving model to trained_vae.h5
# Epoch 65/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8227.8931
#
# Epoch 00065: loss did not improve from 8227.78049
# Epoch 66/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8227.6575
#
# Epoch 00066: loss improved from 8227.78049 to 8227.64451, saving model to trained_vae.h5
# Epoch 67/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8227.2634
#
# Epoch 00067: loss improved from 8227.64451 to 8227.26495, saving model to trained_vae.h5
# Epoch 68/150
# 396/395 [==============================] - 197s 496ms/step - loss: 8227.3075
#
# Epoch 00068: loss did not improve from 8227.26495
# Epoch 69/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8227.0890
#
# Epoch 00069: loss improved from 8227.26495 to 8227.01215, saving model to trained_vae.h5
# Epoch 70/150
# 396/395 [==============================] - 197s 498ms/step - loss: 8227.0014
#
# Epoch 00070: loss improved from 8227.01215 to 8226.96440, saving model to trained_vae.h5
# Epoch 71/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8226.6493
#
# Epoch 00071: loss improved from 8226.96440 to 8226.67669, saving model to trained_vae.h5
# Epoch 72/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8226.4746
#
# Epoch 00072: loss improved from 8226.67669 to 8226.44096, saving model to trained_vae.h5
# Epoch 73/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8226.3109
#
# Epoch 00073: loss improved from 8226.44096 to 8226.36000, saving model to trained_vae.h5
# Epoch 74/150
# 396/395 [==============================] - 199s 503ms/step - loss: 8226.2337
#
# Epoch 00074: loss improved from 8226.36000 to 8226.29489, saving model to trained_vae.h5
# Epoch 75/150
# 396/395 [==============================] - 201s 509ms/step - loss: 8226.2761
#
# Epoch 00075: loss improved from 8226.29489 to 8226.24452, saving model to trained_vae.h5
# Epoch 76/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8226.2128
#
# Epoch 00076: loss did not improve from 8226.24452
# Epoch 77/150
# 396/395 [==============================] - 199s 504ms/step - loss: 8225.6015
#
# Epoch 00077: loss improved from 8226.24452 to 8225.59960, saving model to trained_vae.h5
# Epoch 78/150
# 396/395 [==============================] - 199s 501ms/step - loss: 8225.6377
#
# Epoch 00078: loss did not improve from 8225.59960
# Epoch 79/150
# 396/395 [==============================] - 199s 503ms/step - loss: 8225.7129
#
# Epoch 00079: loss did not improve from 8225.59960
# Epoch 80/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8225.5405
#
# Epoch 00080: loss improved from 8225.59960 to 8225.57663, saving model to trained_vae.h5
# Epoch 81/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8225.2408
#
# Epoch 00081: loss improved from 8225.57663 to 8225.28723, saving model to trained_vae.h5
# Epoch 82/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8225.1321
#
# Epoch 00082: loss improved from 8225.28723 to 8225.11176, saving model to trained_vae.h5
# Epoch 83/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8225.3242
#
# Epoch 00083: loss did not improve from 8225.11176
# Epoch 84/150
# 396/395 [==============================] - 196s 496ms/step - loss: 8224.8079
#
# Epoch 00084: loss improved from 8225.11176 to 8224.86808, saving model to trained_vae.h5
# Epoch 85/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8225.0315
#
# Epoch 00085: loss did not improve from 8224.86808
# Epoch 86/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8224.5905
#
# Epoch 00086: loss improved from 8224.86808 to 8224.57963, saving model to trained_vae.h5
# Epoch 87/150
# 396/395 [==============================] - 199s 501ms/step - loss: 8224.5691
#
# Epoch 00087: loss did not improve from 8224.57963
# Epoch 88/150
# 396/395 [==============================] - 197s 496ms/step - loss: 8224.6733
#
# Epoch 00088: loss did not improve from 8224.57963
# Epoch 89/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8224.3993
#
# Epoch 00089: loss improved from 8224.57963 to 8224.23998, saving model to trained_vae.h5
# Epoch 90/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8224.2237
#
# Epoch 00090: loss did not improve from 8224.23998
# Epoch 91/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8224.3680
#
# Epoch 00091: loss did not improve from 8224.23998
# Epoch 92/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8224.0225
#
# Epoch 00092: loss improved from 8224.23998 to 8224.03187, saving model to trained_vae.h5
# Epoch 93/150
# 396/395 [==============================] - 201s 507ms/step - loss: 8223.9314
#
# Epoch 00093: loss improved from 8224.03187 to 8223.90192, saving model to trained_vae.h5
# Epoch 94/150
# 396/395 [==============================] - 201s 508ms/step - loss: 8224.0908
#
# Epoch 00094: loss did not improve from 8223.90192
# Epoch 95/150
# 396/395 [==============================] - 201s 507ms/step - loss: 8224.0088
#
# Epoch 00095: loss did not improve from 8223.90192
# Epoch 96/150
# 396/395 [==============================] - 197s 499ms/step - loss: 8223.6890
#
# Epoch 00096: loss improved from 8223.90192 to 8223.53356, saving model to trained_vae.h5
# Epoch 97/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8223.6890
#
# Epoch 00097: loss did not improve from 8223.53356
# Epoch 98/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8223.5066
#
# Epoch 00098: loss improved from 8223.53356 to 8223.51440, saving model to trained_vae.h5
# Epoch 99/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8223.4867
#
# Epoch 00099: loss improved from 8223.51440 to 8223.48919, saving model to trained_vae.h5
# Epoch 100/150
# 396/395 [==============================] - 196s 495ms/step - loss: 8223.5523
#
# Epoch 00100: loss did not improve from 8223.48919
# Epoch 101/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8223.1825
#
# Epoch 00101: loss improved from 8223.48919 to 8223.10282, saving model to trained_vae.h5
# Epoch 102/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8223.1093
#
# Epoch 00102: loss improved from 8223.10282 to 8223.07657, saving model to trained_vae.h5
# Epoch 103/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8223.0500
#
# Epoch 00103: loss improved from 8223.07657 to 8223.00307, saving model to trained_vae.h5
# Epoch 104/150
# 396/395 [==============================] - 196s 496ms/step - loss: 8223.0930
#
# Epoch 00104: loss did not improve from 8223.00307
# Epoch 105/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8222.7668
#
# Epoch 00105: loss improved from 8223.00307 to 8222.85787, saving model to trained_vae.h5
# Epoch 106/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8222.9518
#
# Epoch 00106: loss improved from 8222.85787 to 8222.80918, saving model to trained_vae.h5
# Epoch 107/150
# 396/395 [==============================] - 198s 500ms/step - loss: 8222.9244
#
# Epoch 00107: loss did not improve from 8222.80918
# Epoch 108/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8222.5637
#
# Epoch 00108: loss improved from 8222.80918 to 8222.52989, saving model to trained_vae.h5
# Epoch 109/150
# 396/395 [==============================] - 200s 505ms/step - loss: 8222.5096
#
# Epoch 00109: loss did not improve from 8222.52989
# Epoch 110/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8222.4204
#
# Epoch 00110: loss did not improve from 8222.52989
# Epoch 111/150
# 396/395 [==============================] - 199s 503ms/step - loss: 8222.6431
#
# Epoch 00111: loss did not improve from 8222.52989
# Epoch 112/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8222.3712
#
# Epoch 00112: loss improved from 8222.52989 to 8222.37225, saving model to trained_vae.h5
# Epoch 113/150
# 396/395 [==============================] - 203s 511ms/step - loss: 8222.2226
#
# Epoch 00113: loss improved from 8222.37225 to 8222.20445, saving model to trained_vae.h5
# Epoch 114/150
# 396/395 [==============================] - 201s 507ms/step - loss: 8222.3371
#
# Epoch 00114: loss did not improve from 8222.20445
# Epoch 115/150
# 396/395 [==============================] - 201s 507ms/step - loss: 8222.1655
#
# Epoch 00115: loss improved from 8222.20445 to 8222.12273, saving model to trained_vae.h5
# Epoch 116/150
# 396/395 [==============================] - 200s 505ms/step - loss: 8222.1395
#
# Epoch 00116: loss improved from 8222.12273 to 8222.10007, saving model to trained_vae.h5
# Epoch 117/150
# 396/395 [==============================] - 207s 522ms/step - loss: 8222.0236
#
# Epoch 00117: loss improved from 8222.10007 to 8222.00134, saving model to trained_vae.h5
# Epoch 118/150
# 396/395 [==============================] - 202s 510ms/step - loss: 8221.9526
#
# Epoch 00118: loss did not improve from 8222.00134
# Epoch 119/150
# 396/395 [==============================] - 205s 519ms/step - loss: 8221.8397
#
# Epoch 00119: loss improved from 8222.00134 to 8221.82675, saving model to trained_vae.h5
# Epoch 120/150
# 396/395 [==============================] - 200s 505ms/step - loss: 8222.1124
#
# Epoch 00120: loss did not improve from 8221.82675
# Epoch 121/150
# 396/395 [==============================] - 207s 522ms/step - loss: 8221.7747
#
# Epoch 00121: loss improved from 8221.82675 to 8221.74690, saving model to trained_vae.h5
# Epoch 122/150
# 396/395 [==============================] - 206s 519ms/step - loss: 8221.5428
#
# Epoch 00122: loss improved from 8221.74690 to 8221.54873, saving model to trained_vae.h5
# Epoch 123/150
# 396/395 [==============================] - 222s 561ms/step - loss: 8221.6631
#
# Epoch 00123: loss did not improve from 8221.54873
# Epoch 124/150
# 396/395 [==============================] - 200s 506ms/step - loss: 8221.6390
#
# Epoch 00124: loss did not improve from 8221.54873
# Epoch 125/150
# 396/395 [==============================] - 208s 526ms/step - loss: 8221.4287
#
# Epoch 00125: loss improved from 8221.54873 to 8221.34458, saving model to trained_vae.h5
# Epoch 126/150
# 396/395 [==============================] - 202s 509ms/step - loss: 8221.5113
#
# Epoch 00126: loss did not improve from 8221.34458
# Epoch 127/150
# 396/395 [==============================] - 206s 520ms/step - loss: 8221.4526
#
# Epoch 00127: loss did not improve from 8221.34458
# Epoch 128/150
# 396/395 [==============================] - 203s 512ms/step - loss: 8221.2394
#
# Epoch 00128: loss improved from 8221.34458 to 8221.24406, saving model to trained_vae.h5
# Epoch 129/150
# 396/395 [==============================] - 210s 530ms/step - loss: 8277.8380
#
# Epoch 00129: loss did not improve from 8221.24406
# Epoch 130/150
# 396/395 [==============================] - 204s 515ms/step - loss: 8244.6258
#
# Epoch 00130: loss did not improve from 8221.24406
# Epoch 131/150
# 396/395 [==============================] - 207s 524ms/step - loss: 8226.5823
#
# Epoch 00131: loss did not improve from 8221.24406
# Epoch 132/150
# 396/395 [==============================] - 203s 512ms/step - loss: 8223.8328
#
# Epoch 00132: loss did not improve from 8221.24406
# Epoch 133/150
# 396/395 [==============================] - 204s 516ms/step - loss: 8222.6293
#
# Epoch 00133: loss did not improve from 8221.24406
# Epoch 134/150
# 396/395 [==============================] - 200s 506ms/step - loss: 8222.0153
#
# Epoch 00134: loss did not improve from 8221.24406
# Epoch 135/150
# 396/395 [==============================] - 200s 506ms/step - loss: 8221.6096
#
# Epoch 00135: loss did not improve from 8221.24406
# Epoch 136/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8221.5548
#
# Epoch 00136: loss did not improve from 8221.24406
# Epoch 137/150
# 396/395 [==============================] - 201s 508ms/step - loss: 8221.5937
#
# Epoch 00137: loss did not improve from 8221.24406
# Epoch 138/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8221.4201
#
# Epoch 00138: loss did not improve from 8221.24406
# Epoch 139/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8221.2837
#
# Epoch 00139: loss did not improve from 8221.24406
# Epoch 140/150
# 396/395 [==============================] - 197s 497ms/step - loss: 8221.1753
#
# Epoch 00140: loss improved from 8221.24406 to 8221.19723, saving model to trained_vae.h5
# Epoch 141/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8221.2968
#
# Epoch 00141: loss did not improve from 8221.19723
# Epoch 142/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8221.2203
#
# Epoch 00142: loss did not improve from 8221.19723
# Epoch 143/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8221.2169
#
# Epoch 00143: loss improved from 8221.19723 to 8221.17505, saving model to trained_vae.h5
# Epoch 144/150
# 396/395 [==============================] - 198s 501ms/step - loss: 8220.8157
#
# Epoch 00144: loss improved from 8221.17505 to 8220.90886, saving model to trained_vae.h5
# Epoch 145/150
# 396/395 [==============================] - 199s 502ms/step - loss: 8220.8617
#
# Epoch 00145: loss improved from 8220.90886 to 8220.83406, saving model to trained_vae.h5
# Epoch 146/150
# 396/395 [==============================] - 200s 505ms/step - loss: 8220.8971
#
# Epoch 00146: loss did not improve from 8220.83406
# Epoch 147/150
# 396/395 [==============================] - 199s 503ms/step - loss: 8220.6015
#
# Epoch 00147: loss improved from 8220.83406 to 8220.67063, saving model to trained_vae.h5
# Epoch 148/150
# 396/395 [==============================] - 200s 504ms/step - loss: 8220.7756
#
# Epoch 00148: loss did not improve from 8220.67063
# Epoch 149/150
# 396/395 [==============================] - 200s 506ms/step - loss: 8220.5968
#
# Epoch 00149: loss improved from 8220.67063 to 8220.65000, saving model to trained_vae.h5
# Epoch 150/150
# 396/395 [==============================] - 203s 511ms/step - loss: 8220.4820
#
# Epoch 00150: loss improved from 8220.65000 to 8220.55350, saving model to trained_vae.h5
# Comparison of original image and reconstructed image after passing through encoder/decoder
# Newly generated faces.

# %% [markdown]
# So as we can see the vae model manages to reconstruct the faces fairly well. They are blurier so in the second image from the left we can't make out any details in the hair and the fourth image looks different other examples are the fourth from the right which in the original image had his face obstructed while in the reconstruction the obstruction is not there.
#
# As For the fake faces they all look like facesonce again everything other than the face is blurry but this is to be expected since we probably can assume that the background of the original images will vary a lot. What we can say howver is that the model can generate male and female faces of different ethnicities and with different facial angles.
